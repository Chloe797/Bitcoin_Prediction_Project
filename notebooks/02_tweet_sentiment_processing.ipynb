# %% [markdown]
# # Tweet processing and sentiment Analysis for BTC prediction task
#
# This notebook imports, processes and extracts the sentiment from tweets. Usage of this dataset can be found in the notebook 'Data_Final.ipynb'.
#
# The dataset was taken from Kaggle and can be found [here](https://www.kaggle.com/datasets/kaushiksuresh147/bitcoin-tweets).

# %%
# !pip install emoji
# !pip install swifter
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/590.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 23.8 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (2.2.2)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.11/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2024.10.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.6.1)
# Collecting dask-expr<1.2,>=1.1 (from dask[dataframe]>=2.10.0->swifter)
#   Downloading dask_expr-1.1.21-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.1)
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
#   Downloading dask_expr-1.1.20-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.19-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.18-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.16-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.10.0->swifter) (17.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.17.0)
# Downloading dask_expr-1.1.16-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 6.7 MB/s eta 0:00:00
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=c318173326691ef9f23acde6eae8743fcbd9affddd57f5fca7553d8a46568207
#   Stored in directory: /root/.cache/pip/wheels/ef/7f/bd/9bed48f078f3ee1fa75e0b29b6e0335ce1cb03a38d3443b3a3
# Successfully built swifter
# Installing collected packages: dask-expr, swifter
# Successfully installed dask-expr-1.1.16 swifter-1.4.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import kagglehub
import nltk
from nltk import TweetTokenizer
import emoji
import swifter
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
import gc
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
#import path from Kaggle
path = kagglehub.dataset_download("kaushiksuresh147/bitcoin-tweets")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.7).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kaushiksuresh147/bitcoin-tweets?dataset_version_number=54...
# 100%|██████████| 695M/695M [00:37<00:00, 19.7MB/s]
# Extracting files...

# %%
#load data in chunks for efficiency and then concatonate
df0 = pd.read_csv(path + '/Bitcoin_tweets.csv',chunksize=100000,lineterminator='\n', low_memory =False)
df = pd.concat(df0)

# %% [markdown]
# Some quick initial EDA

# %%
#Initial EDA
df.describe()
# Out:
#                 user_name  user_location  \
# count             4689243        2352532
# unique             653022         100599
# top     Live Price Crypto  United States
# freq                41701          63086
#
#                                      user_description         user_created  \
# count                                         4169365              4689354
# unique                                         683981               620891
# top     UP or DOWN...\n.\n.\n.\n.\nPrice matters NOT.  2022-03-10 14:06:46
# freq                                            29410                43465
#
#         user_followers  user_friends  user_favourites user_verified  \
# count        4689354.0     4689354.0        4689354.0       4689354
# unique         92485.0       34319.0         163739.0            70
# top                0.0           0.0              0.0         False
# freq           60579.0      115000.0         181174.0       3066892
#
#                        date  \
# count               4689354
# unique              3668409
# top     2022-05-31 06:02:30
# freq                    373
#
#                                                      text     hashtags  \
# count                                             4689354      4671838
# unique                                            4570199      1013167
# top     💸 Earn free #BTC and multiply crypto up to 15%...  ['Bitcoin']
# freq                                                 1351       608574
#
#                      source is_retweet
# count               4685271    4688536
# unique                 3108          1
# top     Twitter for Android      False
# freq                1281003    4688536

# %%
df.head()
# Out:
#                                   user_name    user_location  \
# 0                             DeSota Wilson      Atlanta, GA
# 1                                  CryptoND              NaN
# 2                                 Tdlmatias  London, England
# 3                      Crypto is the future              NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# 2  IM Academy : The best #forex, #SelfEducation, ...  2014-11-10 10:50:37
# 3  I will post a lot of buying signals for BTC tr...  2019-09-28 16:48:12
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...  2016-02-03 13:15:55
#
#   user_followers user_friends user_favourites user_verified  \
# 0         8534.0         7605            4838         False
# 1         6769.0         1532           25483         False
# 2          128.0          332             924         False
# 3          625.0          129              14         False
# 4         1249.0         1472           10482         False
#
#                   date                                               text  \
# 0  2021-02-10 23:59:04  Blue Ridge Bank shares halted by NYSE after #b...
# 1  2021-02-10 23:58:48  😎 Today, that's this #Thursday, we will do a "...
# 2  2021-02-10 23:54:48  Guys evening, I have read this article about B...
# 3  2021-02-10 23:54:33  $BTC A big chance in a billion! Price: \487264...
# 4  2021-02-10 23:54:06  This network is secured by 9 508 nodes as of t...
#
#                                     hashtags               source is_retweet
# 0                                ['bitcoin']      Twitter Web App      False
# 1  ['Thursday', 'Btc', 'wallet', 'security']  Twitter for Android      False
# 2                                        NaN      Twitter Web App      False
# 3         ['Bitcoin', 'FX', 'BTC', 'crypto']              dlvr.it      False
# 4                                    ['BTC']      Twitter Web App      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4689354 entries, 0 to 4689353
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_name         object
#  1   user_location     object
#  2   user_description  object
#  3   user_created      object
#  4   user_followers    object
#  5   user_friends      object
#  6   user_favourites   object
#  7   user_verified     object
#  8   date              object
#  9   text              object
#  10  hashtags          object
#  11  source            object
#  12  is_retweet        object
# dtypes: object(13)
# memory usage: 465.1+ MB

# %%
df.isnull().sum()
# Out:
# user_name               111
# user_location       2336822
# user_description     519989
# user_created              0
# user_followers            0
# user_friends              0
# user_favourites           0
# user_verified             0
# date                      0
# text                      0
# hashtags              17516
# source                 4083
# is_retweet              818
# dtype: int64

# %% [markdown]
# ## Converting the Dates, Grouping and Sorting.

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

#convert to US/Eastern to allign with alpha_vantage
df['date'] = df['date'].dt.tz_localize('UTC').dt.tz_convert('US/Eastern')

df['date'] = df['date'].dt.date

# %%
df
# Out:
#                                         user_name            user_location  \
# 0                                   DeSota Wilson              Atlanta, GA
# 1                                        CryptoND                      NaN
# 2                                       Tdlmatias          London, England
# 3                            Crypto is the future                      NaN
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader                   Europa
# ...                                           ...                      ...
# 4689349                                 TAnotepad     Not financial advice
# 4689350                                  Boba-Feh  South of the North Pole
# 4689351                             Ethereum Yoda                      NaN
# 4689352                      Bitcoin Price Ticker                      NaN
# 4689353                              faucetojisan                      NaN
#
#                                           user_description  \
# 0        Biz Consultant, real estate, fintech, startups...
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...
# 2        IM Academy : The best #forex, #SelfEducation, ...
# 3        I will post a lot of buying signals for BTC tr...
# 4        Co-founder @RENJERJerky | Forbes 30Under30 | I...
# ...                                                    ...
# 4689349  #Bitcoin | Forever Alone Crypto Trader 😭 | Ana...
# 4689350         My backpack has jets. Reformed Necromonger
# 4689351      UP or DOWN...\n.\n.\n.\n.\nPrice matters NOT.
# 4689352  Tweets the current price of #bitcoin every 5 m...
# 4689353  💰faucetpay 👉\nhttps://t.co/eHqMw9QdFx\n\n💰betf...
#
#                 user_created user_followers user_friends user_favourites  \
# 0        2009-04-26 20:05:09         8534.0         7605            4838
# 1        2019-10-17 20:12:10         6769.0         1532           25483
# 2        2014-11-10 10:50:37          128.0          332             924
# 3        2019-09-28 16:48:12          625.0          129              14
# 4        2016-02-03 13:15:55         1249.0         1472           10482
# ...                      ...            ...          ...             ...
# 4689349  2022-11-04 10:18:11            674         1789           27466
# 4689350  2008-04-02 21:48:47             79          454             125
# 4689351  2022-07-24 04:50:18            532            1               0
# 4689352  2022-10-20 07:10:38             83            7               9
# 4689353  2022-10-13 05:41:53             14           10               0
#
#         user_verified        date  \
# 0               False  2021-02-10
# 1               False  2021-02-10
# 2               False  2021-02-10
# 3               False  2021-02-10
# 4               False  2021-02-10
# ...               ...         ...
# 4689349         False  2023-01-06
# 4689350         False  2023-01-06
# 4689351         False  2023-01-06
# 4689352         False  2023-01-06
# 4689353         False  2023-01-06
#
#                                                       text  \
# 0        Blue Ridge Bank shares halted by NYSE after #b...
# 1        😎 Today, that's this #Thursday, we will do a "...
# 2        Guys evening, I have read this article about B...
# 3        $BTC A big chance in a billion! Price: \487264...
# 4        This network is secured by 9 508 nodes as of t...
# ...                                                    ...
# 4689349  Bitcoin squeeze is SUPER TIGHT, which way will...
# 4689350  Closed #BTC short at 16725. Missed my long pla...
# 4689351  #Ethereum price update: \n\n#ETH $1263.59 USD\...
# 4689352  1₿ = $16814.7 -0.07%🔻\n\nDetails:\nChange: 🔻-1...
# 4689353  Earn crypto by playing fun games online.\nGet ...
#
#                                                   hashtags  \
# 0                                              ['bitcoin']
# 1                ['Thursday', 'Btc', 'wallet', 'security']
# 2                                                      NaN
# 3                       ['Bitcoin', 'FX', 'BTC', 'crypto']
# 4                                                  ['BTC']
# ...                                                    ...
# 4689349  ['BTC', 'bitcoin', 'Crypto', 'cryptocurrency',...
# 4689350                                            ['BTC']
# 4689351  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin...
# 4689352                                 ['bitcoin', 'btc']
# 4689353                     ['faucet', 'cointiply', 'BTC']
#
#                          source is_retweet
# 0               Twitter Web App      False
# 1           Twitter for Android      False
# 2               Twitter Web App      False
# 3                       dlvr.it      False
# 4               Twitter Web App      False
# ...                         ...        ...
# 4689349     Twitter for Android      False
# 4689350     Twitter for Android      False
# 4689351         Twitter Web App      False
# 4689352  BitcoinLivePriceTicker      False
# 4689353     Twitter for Android      False
#
# [4689354 rows x 13 columns]

# %%
#sort dataframe by date
df = df.sort_values(by='date', ascending=True)
df.head()
# Out:
#               user_name  user_location  \
# 19595     Alexis Butler  Colorado, USA
# 20025      Hunar Campus            NaN
# 20026      Ether🩸Reaper            NaN
# 20027  #MakeADifference         Online
# 20028      𝘾𝙧𝙮𝙥𝙩𝙤𝙃𝙪𝙣𝙩𝙚𝙧            NaN
#
#                                         user_description         user_created  \
# 19595  Helping agency owners hit 7-figures in 2021. 💰...  2012-05-29 16:09:25
# 20025                                   Skills Redefined  2021-01-05 10:18:50
# 20026  Founder: Reaper’s🏔Valhalla / #NFT artist / cry...  2015-06-08 09:18:38
# 20027  Are you ready to make a difference?\n\nGet $10...  2015-05-02 16:54:25
# 20028  Technical Analyst ° Crypto Trader ° Swing & Sc...  2018-01-04 16:16:20
#
#       user_followers user_friends user_favourites user_verified        date  \
# 19595          178.0           14             210         False  2021-02-05
# 20025            0.0            1               0         False  2021-02-05
# 20026         1721.0          621           35273         False  2021-02-05
# 20027        78779.0        46656          120855         False  2021-02-05
# 20028        16265.0           79            8790         False  2021-02-05
#
#                                                     text  \
# 19595  Last Week I Broke a Record &amp; Made $15,000 ...
# 20025  Last business model to be discussed is that of...
# 20026  I am pleased to present, The Digging Badger. \...
# 20027  https://t.co/h0XWfZiGQM Market Wrap: #Bitcoin ...
# 20028  #unfi $unfi Easy money ?\n\n#btc #bitcoin http...
#
#                                            hashtags              source  \
# 19595                                           NaN  Twitter for iPhone
# 20025        ['wazirxwarriors', 'indiawantscrypto']     Twitter Web App
# 20026  ['NFT', 'ETH', 'BTC', 'Bitcoin', 'Ethereum']  Twitter for iPhone
# 20027                                   ['Bitcoin']          Twibble.io
# 20028                    ['unfi', 'btc', 'bitcoin']     Twitter Web App
#
#       is_retweet
# 19595      False
# 20025      False
# 20026      False
# 20027      False
# 20028      False

# %%
df_day = df.groupby('date').count() #Counts the number of entries in each group, returns the number of non-null entries for each group.
df_day
# Out:
#             user_name  user_location  user_description  user_created  \
# date
# 2021-02-05       2237           1298              2048          2237
# 2021-02-06       3249           1946              3029          3249
# 2021-02-07       2915           1777              2670          2915
# 2021-02-08       6242           3761              5842          6242
# 2021-02-09       3954           2317              3670          3955
# ...               ...            ...               ...           ...
# 2022-12-27      17069           8169             15480         17069
# 2023-01-06       7013           2986              6559          7014
# 2023-01-07      20114           9355             18637         20114
# 2023-01-08       7666           3661              7171          7666
# 2023-01-09      26093          13555             24509         26093
#
#             user_followers  user_friends  user_favourites  user_verified  \
# date
# 2021-02-05            2237          2237             2237           2237
# 2021-02-06            3249          3249             3249           3249
# 2021-02-07            2915          2915             2915           2915
# 2021-02-08            6242          6242             6242           6242
# 2021-02-09            3955          3955             3955           3955
# ...                    ...           ...              ...            ...
# 2022-12-27           17069         17069            17069          17069
# 2023-01-06            7014          7014             7014           7014
# 2023-01-07           20114         20114            20114          20114
# 2023-01-08            7666          7666             7666           7666
# 2023-01-09           26093         26093            26093          26093
#
#              text  hashtags  source  is_retweet
# date
# 2021-02-05   2237      1655    2218        2237
# 2021-02-06   3249      2474    3214        3249
# 2021-02-07   2915      2230    2878        2915
# 2021-02-08   6242      5136    6187        6242
# 2021-02-09   3955      3080    3915        3955
# ...           ...       ...     ...         ...
# 2022-12-27  17069     17069   17069       17069
# 2023-01-06   7014      7014    7014        7014
# 2023-01-07  20114     20114   20114       20114
# 2023-01-08   7666      7666    7666        7666
# 2023-01-09  26093     26093   26093       26093
#
# [224 rows x 12 columns]

# %% [markdown]
# We can see here that we have 224 dates. The range 2021/02/05	-> 2023/01/09 should have 704 days, meaning we are missing 480. This is only a third of the dates represented in the dataset. Therefore we will take a smaller subset as 'imputing' a smaller subset, hopefully means filling smaller gaps.

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
#creating subset of data
start_range = pd.to_datetime('2022-01-01')
end_range = pd.to_datetime('2022-06-30')


df['date'] = pd.to_datetime(df['date'])
df_short_term = df[(df['date'] >= start_range) & (df['date'] <= end_range)] #.copy()
df_short_term.head(10)
# Out:
#                user_name                   user_location  \
# 2111285    satsleft.info           The Bitcoin Timechain
# 2111282        Sandbaad2                             NaN
# 2111283     ₿TC ₿lock₿ot  Ubuntu Bx Undisclosed Location
# 2111284  tictoknextblock                             NaN
# 2111281        Sandbaad2                             NaN
# 2111286    TokenPrice.cc                      Blockchain
# 2111294        Sandbaad2                             NaN
# 2111288          Maxwell                   Massachusetts
# 2111289        Sandbaad2                             NaN
# 2111290      Igloobamboo                          Hexico
#
#                                           user_description  \
# 2111285  Reporting on the remaining #Bitcoin supply to ...
# 2111282                                                NaN
# 2111283  Keeping you up to date on the latest BTC Block...
# 2111284                        Real-time bitcoin  insights
# 2111281                                                NaN
# 2111286  https://t.co/qYUjk6bzEq provides fundamental a...
# 2111294                                                NaN
# 2111288  Be the change you want to see in the world.\nM...
# 2111289                                                NaN
# 2111290  Richard Heart maximalist who missed out on HEX...
#
#                 user_created user_followers user_friends user_favourites  \
# 2111285  2021-10-14 21:31:42          230.0        362.0            37.0
# 2111282  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111283  2019-11-21 22:08:19          359.0         72.0            34.0
# 2111284  2021-07-01 03:29:10          174.0         11.0             1.0
# 2111281  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111286  2021-08-26 21:48:29        11923.0         35.0          1202.0
# 2111294  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111288  2021-05-13 01:45:34            1.0          5.0            13.0
# 2111289  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111290  2021-08-16 18:02:56         2397.0       2497.0         31741.0
#
#         user_verified       date  \
# 2111285         False 2022-01-11
# 2111282         False 2022-01-11
# 2111283         False 2022-01-11
# 2111284         False 2022-01-11
# 2111281         False 2022-01-11
# 2111286         False 2022-01-11
# 2111294         False 2022-01-11
# 2111288         False 2022-01-11
# 2111289         False 2022-01-11
# 2111290         False 2022-01-11
#
#                                                       text  \
# 2111285  👋 A new block was found on the #Bitcoin networ...
# 2111282  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111283  $BTC Latest Block Info: Block 718220 holds 2,5...
# 2111284  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 2111281  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111286  #Bitcoin = BOSS\n\n#tokenpricecc #Crypto #cryp...
# 2111294  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111288  @binance My investments for 2022:\n$3K in #bit...
# 2111289  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111290  You're going to want to sub this new YouTube c...
#
#                                                   hashtags  \
# 2111285                     ['Bitcoin', 'bitcoin', 'sats']
# 2111282  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111283                                        ['Bitcoin']
# 2111284                     ['bitcoin', 'tictoknextblock']
# 2111281  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111286  ['Bitcoin', 'tokenpricecc', 'Crypto', 'cryptoc...
# 2111294  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111288                                        ['bitcoin']
# 2111289  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111290  ['Bitcoin', 'Ethereum', 'MATIC', 'Chainlink', ...
#
#                       source is_retweet
# 2111285             satsleft      False
# 2111282  Twitter for Android      False
# 2111283         BTC_BlockBot      False
# 2111284      tictoknextblock      False
# 2111281  Twitter for Android      False
# 2111286      Twitter Web App      False
# 2111294  Twitter for Android      False
# 2111288      Twitter Web App      False
# 2111289  Twitter for Android      False
# 2111290  Twitter for Android      False

# %%
df_short_term.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1819005 entries, 2111285 to 3786421
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_name         object
#  1   user_location     object
#  2   user_description  object
#  3   user_created      object
#  4   user_followers    object
#  5   user_friends      object
#  6   user_favourites   object
#  7   user_verified     object
#  8   date              datetime64[ns]
#  9   text              object
#  10  hashtags          object
#  11  source            object
#  12  is_retweet        object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 194.3+ MB

# %%
df_short_term.tail()
# Out:
#               user_name                   user_location  \
# 3786418    Chris Taylor                       Cape Town
# 3786419  Lucky Station💳                             NaN
# 3786420           Ross                              EU
# 3786413           mohak                             NaN
# 3786421     Gerald Bull  Lost,in a world full of Grace.
#
#                                           user_description  \
# 3786418              Bitcoin ☀️ \nTravel 🌍\nNadia Taylor ❤
# 3786419  Consultant Independent en suivi-evaluation des...
# 3786420  🚀\n 🐱cat moms, \n🍷food, 📸📸photography,\n 🇪🇺tra...
# 3786413                            https://t.co/cmJyjarhsr
# 3786421  Eng/Design/Fabrication/& Aero-Rube, 70k hrs of...
#
#                 user_created user_followers user_friends user_favourites  \
# 3786418  2011-02-20 13:29:26         2995.0        758.0         16003.0
# 3786419  2022-04-24 11:19:21           31.0        133.0             0.0
# 3786420  2013-12-27 11:17:48         1680.0       1214.0          4233.0
# 3786413  2014-10-08 17:44:47          106.0       1511.0          2078.0
# 3786421  2021-05-11 13:46:15           40.0         87.0          1179.0
#
#         user_verified       date  \
# 3786418         False 2022-06-29
# 3786419         False 2022-06-29
# 3786420         False 2022-06-29
# 3786413         False 2022-06-29
# 3786421         False 2022-06-29
#
#                                                       text  \
# 3786418  Saudi Saylor is buying #bitcoin 🇸🇦 https://t.c...
# 3786419  If #Bitcoin  doesn't reach $50,000 by April 20...
# 3786420  After June’s volatility and challenges, #Bitco...
# 3786413  Keep Up With Crypto in Just Minutes -\nCut thr...
# 3786421  @TXMCtrades I like #Bitcoin  &amp; Im glad U s...
#
#                                                   hashtags  \
# 3786418                                        ['bitcoin']
# 3786419                                        ['Bitcoin']
# 3786420                                        ['Bitcoin']
# 3786413  ['cryptonews', 'nft', 'ether', 'altcoin', 'web...
# 3786421                                        ['Bitcoin']
#
#                       source is_retweet
# 3786418  Twitter for Android      False
# 3786419      Twitter Web App      False
# 3786420      Twitter Web App      False
# 3786413        WordPress.com      False
# 3786421      Twitter Web App      False

# %%
df_day_2 = df_short_term.groupby('date').count()

# %%
print(len(df_day_2))
# Out:
# 77

# %% [markdown]
# As you can see we have 76 unique days, out of 170 meaning we have tweets for 45% of the time period which is an improvement from earlier.
# The first and second halves of 2022 were tested.

# %% [markdown]
# ## Investigating Useful Columns

# %%
print(len(df_short_term))
# Out:
# 1819005

# %%
print(df_short_term['is_retweet'].dtype)
# Out:
# object

# %%
df_short_term.isna().sum()
# Out:
# user_name               12
# user_location       932243
# user_description    217010
# user_created             0
# user_followers           0
# user_friends             0
# user_favourites          0
# user_verified            0
# date                     0
# text                     0
# hashtags                54
# source                  51
# is_retweet              51
# dtype: int64

# %%
print(df_short_term['is_retweet'].unique())
# Out:
# [False nan]

# %%
print(df_short_term['user_verified'].unique())
# Out:
# [False True 'False' 'True']

# %%
df_short_term.head(20)
# Out:
#                      user_name                   user_location  \
# 2111285          satsleft.info           The Bitcoin Timechain
# 2111282              Sandbaad2                             NaN
# 2111283           ₿TC ₿lock₿ot  Ubuntu Bx Undisclosed Location
# 2111284        tictoknextblock                             NaN
# 2111281              Sandbaad2                             NaN
# 2111286          TokenPrice.cc                      Blockchain
# 2111294              Sandbaad2                             NaN
# 2111288                Maxwell                   Massachusetts
# 2111289              Sandbaad2                             NaN
# 2111290            Igloobamboo                          Hexico
# 2111296  MinaPirate.PlanZ💜🏴‍☠️                       Metaverse
# 2111291                Hoarder                             NaN
# 2111292           Growthsights                             NaN
# 2111295         Papa Jhe Sauce                             NaN
# 2111293        Hideousfinality        Mpumalanga, South Africa
# 2111287       Don Jon Blaze 🔥🦬                      Austin, TX
# 2111280              Sandbaad2                             NaN
# 2111264              DrunkleMo                  Shakertits, OH
# 2111278          Mohamed Ameen                         Germany
# 2111259          Pandamn__it!!                             NaN
#
#                                           user_description  \
# 2111285  Reporting on the remaining #Bitcoin supply to ...
# 2111282                                                NaN
# 2111283  Keeping you up to date on the latest BTC Block...
# 2111284                        Real-time bitcoin  insights
# 2111281                                                NaN
# 2111286  https://t.co/qYUjk6bzEq provides fundamental a...
# 2111294                                                NaN
# 2111288  Be the change you want to see in the world.\nM...
# 2111289                                                NaN
# 2111290  Richard Heart maximalist who missed out on HEX...
# 2111296  85% #Crypto Charts and wisdoms. 10% about my l...
# 2111291                              Meet me at the summit
# 2111292                                                NaN
# 2111295                                  Jhesauce is alive
# 2111293                                                NaN
# 2111287  #bitcoin and Decred fanatic\nFull Time Crypto ...
# 2111280                                                NaN
# 2111264  listener of music, maker of babies, drinker of...
# 2111278  #Bitcoin and Crypto analysis | SW Architect @B...
# 2111259  broadcasting bitcoin blocks. #Bitcoin has a pu...
#
#                 user_created user_followers user_friends user_favourites  \
# 2111285  2021-10-14 21:31:42          230.0        362.0            37.0
# 2111282  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111283  2019-11-21 22:08:19          359.0         72.0            34.0
# 2111284  2021-07-01 03:29:10          174.0         11.0             1.0
# 2111281  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111286  2021-08-26 21:48:29        11923.0         35.0          1202.0
# 2111294  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111288  2021-05-13 01:45:34            1.0          5.0            13.0
# 2111289  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111290  2021-08-16 18:02:56         2397.0       2497.0         31741.0
# 2111296  2017-04-28 16:22:56         1696.0        857.0          1847.0
# 2111291  2013-08-19 14:04:32           25.0        410.0          8500.0
# 2111292  2021-08-25 12:11:52           24.0        260.0           731.0
# 2111295  2021-12-26 13:06:17           13.0         67.0           397.0
# 2111293  2021-12-12 07:49:19            6.0        160.0             5.0
# 2111287  2010-05-17 18:49:21         2589.0        940.0        118410.0
# 2111280  2021-11-29 14:37:03          212.0        589.0         10717.0
# 2111264  2009-02-20 19:46:46          151.0        220.0           635.0
# 2111278  2011-02-13 19:06:02         1233.0        823.0            46.0
# 2111259  2013-05-25 10:36:36           98.0        163.0           135.0
#
#         user_verified       date  \
# 2111285         False 2022-01-11
# 2111282         False 2022-01-11
# 2111283         False 2022-01-11
# 2111284         False 2022-01-11
# 2111281         False 2022-01-11
# 2111286         False 2022-01-11
# 2111294         False 2022-01-11
# 2111288         False 2022-01-11
# 2111289         False 2022-01-11
# 2111290         False 2022-01-11
# 2111296         False 2022-01-11
# 2111291         False 2022-01-11
# 2111292         False 2022-01-11
# 2111295         False 2022-01-11
# 2111293         False 2022-01-11
# 2111287         False 2022-01-11
# 2111280         False 2022-01-11
# 2111264         False 2022-01-11
# 2111278         False 2022-01-11
# 2111259         False 2022-01-11
#
#                                                       text  \
# 2111285  👋 A new block was found on the #Bitcoin networ...
# 2111282  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111283  $BTC Latest Block Info: Block 718220 holds 2,5...
# 2111284  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 2111281  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111286  #Bitcoin = BOSS\n\n#tokenpricecc #Crypto #cryp...
# 2111294  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111288  @binance My investments for 2022:\n$3K in #bit...
# 2111289  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111290  You're going to want to sub this new YouTube c...
# 2111296  $Mina vs $Sol first year\nUpdate 2\n\nIf the m...
# 2111291  Take part in systems that enable you to be ind...
# 2111292  What’s your view? One year from now 👀\n\n#bitc...
# 2111295  @danbouwer @tferriss Step by Step we are going...
# 2111293  @airdropinspect Hey I joined a network called ...
# 2111287  @ChicagoJoe5805 @bigmarh Ah dammit.\n\nPack it...
# 2111280  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111264  Sports book, table games, slots, bitcoin frien...
# 2111278  The first step in a perspective short-term rel...
# 2111259  #bitcoin Block #718221 : 1333905 bytes, 1900 t...
#
#                                                   hashtags  \
# 2111285                     ['Bitcoin', 'bitcoin', 'sats']
# 2111282  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111283                                        ['Bitcoin']
# 2111284                     ['bitcoin', 'tictoknextblock']
# 2111281  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111286  ['Bitcoin', 'tokenpricecc', 'Crypto', 'cryptoc...
# 2111294  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111288                                        ['bitcoin']
# 2111289  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111290  ['Bitcoin', 'Ethereum', 'MATIC', 'Chainlink', ...
# 2111296  ['MinaProtocol', 'Solana', 'Bitcoin', 'Crypto'...
# 2111291                                        ['Bitcoin']
# 2111292  ['bitcoin', 'cryptocurrency', 'investing', 'bi...
# 2111295  ['CryptoIsland', 'CislaArmy', 'CISLA', 'bitcoi...
# 2111293                  ['SurveyJ', 'cashapp', 'bitcoin']
# 2111287                                        ['bitcoin']
# 2111280  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111264  ['sportsbook', 'gamble', 'gambling', 'sportsbe...
# 2111278                                        ['Bitcoin']
# 2111259                                        ['bitcoin']
#
#                         source is_retweet
# 2111285               satsleft      False
# 2111282    Twitter for Android      False
# 2111283           BTC_BlockBot      False
# 2111284        tictoknextblock      False
# 2111281    Twitter for Android      False
# 2111286        Twitter Web App      False
# 2111294    Twitter for Android      False
# 2111288        Twitter Web App      False
# 2111289    Twitter for Android      False
# 2111290    Twitter for Android      False
# 2111296        Twitter Web App      False
# 2111291     Twitter for iPhone      False
# 2111292     Twitter for iPhone      False
# 2111295    Twitter for Android      False
# 2111293    Twitter for Android      False
# 2111287        Twitter Web App      False
# 2111280    Twitter for Android      False
# 2111264     Twitter for iPhone      False
# 2111278        Twitter Web App      False
# 2111259  Bitcoin Block Watcher      False

# %% [markdown]
# ## Columns to drop
# We can see from above 'is_retweet' is either False or NaN, it provides no useful information.
# Other columns that should be removed either for anonymity or lack of information are:
#
# *  user_name - ethical
# *  user_location - either NaN, not reliable
# *  user_description - not helpful here
# * user_created
# * user_friends - enough information in 'user_followers'
# * user_verified
# * source
# * is_retweet - all False or NaN

# %%
df_short_term = df_short_term.drop(columns=['user_name', 'user_location', 'user_description', 'user_created', 'user_friends', 'user_verified', 'source', 'is_retweet'])

# %%
df_short_term.head()
# Out:
#         user_followers user_favourites       date  \
# 2111285          230.0            37.0 2022-01-11
# 2111282          212.0         10717.0 2022-01-11
# 2111283          359.0            34.0 2022-01-11
# 2111284          174.0             1.0 2022-01-11
# 2111281          212.0         10717.0 2022-01-11
#
#                                                       text  \
# 2111285  👋 A new block was found on the #Bitcoin networ...
# 2111282  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111283  $BTC Latest Block Info: Block 718220 holds 2,5...
# 2111284  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 2111281  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
#
#                                                   hashtags
# 2111285                     ['Bitcoin', 'bitcoin', 'sats']
# 2111282  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...
# 2111283                                        ['Bitcoin']
# 2111284                     ['bitcoin', 'tictoknextblock']
# 2111281  ['BlueSparrow', 'BestDrawToken', 'web3', 'Bitc...

# %%
df_short_term.isnull().sum()
# Out:
# user_followers      0
# user_favourites     0
# date                0
# text                0
# hashtags           54
# dtype: int64

# %%
df_short_term['hashtags'].unique()
# Out:
# array(["['Bitcoin', 'bitcoin', 'sats']",
#        "['BlueSparrow', 'BestDrawToken', 'web3', 'Bitcoin']",
#        "['Bitcoin']", ...,
#        "['socialmediamarketing', 'socialmedia', 'affiliatemarketing', 'pinterest', 'workfromhome', 'seo', 'facebook', 'onlinemarketing', 'bitcoin', 'affiliatemarketer']",
#        "['bitcoin', 'Crypto', 'wildwest', 'gosayhello', 'fire', 'burn', 'grayscale', '3AC', 'whales', 'bears', 'crooks']",
#        "['Bitcoin', 'cryptocurrecy', 'cryptotrade']"], dtype=object)

# %%
#for efficient computing just keep tweet text and date for processing
df_text = df_short_term.drop(columns=['user_followers' ,	'user_favourites' ,	'hashtags'])

# %%
df_text
# Out:
#               date                                               text
# 2111285 2022-01-11  👋 A new block was found on the #Bitcoin networ...
# 2111282 2022-01-11  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# 2111283 2022-01-11  $BTC Latest Block Info: Block 718220 holds 2,5...
# 2111284 2022-01-11  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 2111281 2022-01-11  @ianheinischmma @ShannonBrayNC Huuuuge News!!!...
# ...            ...                                                ...
# 3786418 2022-06-29  Saudi Saylor is buying #bitcoin 🇸🇦 https://t.c...
# 3786419 2022-06-29  If #Bitcoin  doesn't reach $50,000 by April 20...
# 3786420 2022-06-29  After June’s volatility and challenges, #Bitco...
# 3786413 2022-06-29  Keep Up With Crypto in Just Minutes -\nCut thr...
# 3786421 2022-06-29  @TXMCtrades I like #Bitcoin  &amp; Im glad U s...
#
# [1819005 rows x 2 columns]

# %% [markdown]
# ## Tweet Preprocessing for Sentiment Analysis
# *  Use Regex to replace any long URLs and any @Users (anonymity)
# *  Use Tweet Tokenizer to tokenize the text
# *  Use the emoji package to keep sentiment of emojis
# *  Vader used to extract sentiment score
#
# Resources on Applying sentiment analysis and Vader can be found here:
# * [Applying Sentiment Analysis](https://www.learndatasci.com/tutorials/sentiment-analysis-reddit-headlines-pythons-nltk/?utm_source=chatgpt.com)
# * [VADER](https://hex.tech/templates/sentiment-analysis/vader-sentiment-analysis/#:~:text=VADER%20is%20a%20rule%2Dbased,with%20their%20corresponding%20sentiment%20ratings.)
# * [Tweet Tokenizer](https://www.geeksforgeeks.org/python-nltk-nltk-tweettokenizer/)

# %%
#Replacing links and tags
gc.disable() #stop garbage collection
df_text['text'] = df_text['text'].str.replace(r'http\S+', 'URL', regex=True)
df_text['text'] = df_text['text'].str.replace(r'@\S+', '@USER', regex=True)

# %%
df_text.head()
# Out:
#               date                                               text
# 2111285 2022-01-11  👋 A new block was found on the #Bitcoin networ...
# 2111282 2022-01-11  @USER @USER Huuuuge News!!!\nNew Utility Incom...
# 2111283 2022-01-11  $BTC Latest Block Info: Block 718220 holds 2,5...
# 2111284 2022-01-11  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 2111281 2022-01-11  @USER @USER Huuuuge News!!!\nNew Utility Incom...

# %%
#preprocessing

#initialize tokenizer
tokenizer = TweetTokenizer()
model = SentimentIntensityAnalyzer()

#preprocessing function
def text_preprocessing(text):
  if pd.isna(text) or text.strip() == '':
    return text

  text = emoji.demojize(text)

  tokens = tokenizer.tokenize(text)

  return tokens


def score_extraction(text):
  score = model.polarity_scores(text)
  compound = score['compound']

  if compound > 0.05:
    sentiment = 'Positive'
  elif compound < -0.05:
    sentiment = 'Negative'
  else:
    sentiment = 'Neutral'

  return sentiment, compound

# %% [markdown]
# Applying the Sentiment Analysis

# %%
#apply to chunks and cocatenate for effciency and  use swifter

chunk_size = 50000
chunks = [df_text[i:i+chunk_size].copy() for i in range(0, len(df_text), chunk_size)]

processed_chunks = []

for chunk in chunks:
  chunk['processed_text'] = chunk['text'].swifter.apply(text_preprocessing)
  chunk[['sentiment', 'compound_score']] = chunk['text'].swifter.apply(lambda x: pd.Series(score_extraction(x))).rename({0: 'sentiment', 1: 'compound_score'}, axis=1)
  processed_chunks.append(chunk)

df_processed = pd.concat(processed_chunks, ignore_index=True)
# Out:
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/50000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/19005 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/19005 [00:00<?, ?it/s]

# %%
df_processed.head()
# Out:
#         date                                               text  \
# 0 2022-01-11  👋 A new block was found on the #Bitcoin networ...
# 1 2022-01-11  @USER @USER Huuuuge News!!!\nNew Utility Incom...
# 2 2022-01-11  $BTC Latest Block Info: Block 718220 holds 2,5...
# 3 2022-01-11  🟩 Block 718220 ⛏ ⛏\n\n📅 11th Jan 2022, 22:12:3...
# 4 2022-01-11  @USER @USER Huuuuge News!!!\nNew Utility Incom...
#
#                                       processed_text sentiment  compound_score
# 0  [:, waving_hand, :, A, new, block, was, found,...  Negative         -0.7003
# 1  [@USER, @USER, Huuuuge, News, !, !, !, New, Ut...  Negative         -0.3530
# 2  [$, BTC, Latest, Block, Info, :, Block, 718220...  Negative         -0.7845
# 3  [:, green_square, :, Block, 718220, :p, ick, :...  Positive          0.2500
# 4  [@USER, @USER, Huuuuge, News, !, !, !, New, Ut...  Negative         -0.3530

# %% [markdown]
# # Creating a dataset just with the day and sentiment score

# %%
#get daily average sentiment score
tweet_daily_sentiment = df_processed.groupby('date').agg(avg_sentiment_score = ('compound_score', 'mean')).reset_index()
print(tweet_daily_sentiment)
# Out:
#          date  avg_sentiment_score
# 0  2022-01-11             0.210110
# 1  2022-01-12             0.260047
# 2  2022-01-13             0.222628
# 3  2022-01-14             0.253282
# 4  2022-01-19             0.208571
# ..        ...                  ...
# 72 2022-06-24             0.154576
# 73 2022-06-25             0.179629
# 74 2022-06-26             0.195231
# 75 2022-06-28             0.151321
# 76 2022-06-29             0.158009
#
# [77 rows x 2 columns]

# %% [markdown]
# # Saving the dataset for future use

# %%
#saving files to CSV in Google Drive
from google.colab import drive
drive.mount('/content/drive')


#file_path = '/content/drive/MyDrive/ML-project/processed_tweets_final.csv'
file_path_1 = '/content/drive/MyDrive/ML-project/tweet_daily_sentiment_final.csv'

# Save DF as CSV
#df_processed.to_csv(file_path, index=False)
tweet_daily_sentiment.to_csv(file_path_1, index=False)

#print(f"File saved to: {file_path}")
print(f"File saved to: {file_path_1}")
# Out:
# Mounted at /content/drive
# File saved to: /content/drive/MyDrive/processed_tweets_final.csv
# File saved to: /content/drive/MyDrive/tweet_daily_sentiment_final.csv

# %% [markdown]
# We will now use this dataset in 'Data_Final.ipynb'. Note this notebook could be pasted at the beginning of the next notebook. However, due to RAM issues, this is not reccomended. This notebook can be run with CPU/T4 GPU (Set to T4 here).
